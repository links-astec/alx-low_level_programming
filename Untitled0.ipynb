# %% [markdown]
# <a href="https://colab.research.google.com/github/links-astec/alx-low_level_programming/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas  as pd
heart=pd.read_csv("heart.csv")
heart=heart[["Age","Sex","ChestPainType","RestingBP","Cholesterol","FastingBS","RestingECG","MaxHR","ExerciseAngina","Oldpeak","ST_Slope","HeartDisease"]]
#heart.corr()["HeartDisease"]
import seaborn as ss
#ss.lmplot(x="HeartDisease",y="RestingBP",data=heart, fit_reg=True, ci=None)
train=heart[heart["MaxHR"]<140].copy()
test=heart[heart["MaxHR"]>=140].copy()
#train.shape
#test.shape
from sklearn.linear_model import LinearRegression
reg=LinearRegression()
predictors=["Age","Cholesterol","RestingBP","Oldpeak"]
target="HeartDisease"
reg.fit(train[predictors],train["HeartDisease"])
LinearRegression()
predictions=reg.predict(test[predictors])
test["predictions"]=predictions
test.loc[test["predictions"]<0.5,"predictions"]=0
test.loc[test["predictions"]>0.5,"predictions"]=1
from sklearn.metrics import mean_absolute_error
error=mean_absolute_error(test["HeartDisease"],test["predictions"])
#error
heart.describe()["HeartDisease"]
test[test["Cholesterol"]=="289"]
# Out:
# Empty DataFrame
# Columns: [Age, Sex, ChestPainType, RestingBP, Cholesterol, FastingBS, RestingECG, MaxHR, ExerciseAngina, Oldpeak, ST_Slope, HeartDisease, predictions]
# Index: []
